# %% [markdown]
# # Step 4: Demo Agent
#
# Verify the deployed agent endpoint on Databricks. Installs PyPI dependencies,
# then imports and runs `check_endpoint()` from `step4_demo_agent.py`.

# %%
# %pip install requests databricks-sdk
dbutils.library.restartPython()

# %%
from retail_agent.step4_demo_agent import check_endpoint

check_endpoint()
